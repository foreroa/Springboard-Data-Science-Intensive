# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import bokeh.plotting as bkp
from mpl_toolkits.axes_grid1 import make_axes_locatable
# %matplotlib inline

# %%
from sklearn.cross_validation import KFold
from sklearn.metrics import accuracy_score
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.metrics import roc_auc_score
from sklearn.cross_validation import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
# Read in data

pipeline = pd.read_excel('PipelineMultiClass2.xlsx')

# %%
# drop the Win_Lose column, so that all other features can be used as the x values.  There are 38 features

X = pipeline.drop('Multiclass', axis = 1)

# %%
# the Win_Lose column is the target column or y value

y = pipeline['Multiclass']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators=200)

# %%
# Train test split using 33% split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=200, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test,rfc_pred))
print('\n')
print(classification_report(y_test,rfc_pred))
# Out:
# [[ 695  195   74]
#  [ 244 1283   56]
#  [ 124  153 2014]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.65      0.72      0.69       964
#           1       0.79      0.81      0.80      1583
#           2       0.94      0.88      0.91      2291
#
# avg / total       0.83      0.83      0.83      4838

# %%
new_df = X_test

# %%
new_df["Predicted_Labels"] = rfc_pred

new_df["Original_Labels"] = y_test


new_df.head(12)
# Out:
# C:\Users\aforero\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\aforero\AppData\Local\Continuum\Anaconda2\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#        BidWin%  Fiscal_Year  AdjEstimatedBase+OptionDuration       Amount  \
# 10550      0.0         2017                               15         0.00
# ...

# %%
# Write dataframe to a csv file with the name my_solution_one.csv

new_df.to_csv("my_solution_one.csv")

# %%
rfc_train = rfc.predict(X_train)

# %%
rfc_train
# Out:
# array([2, 1, 2, ..., 1, 0, 2], dtype=int64)

# %%
from pandas import Series, DataFrame

# %%
# Set a DataFrame containing the X_test Amount column, the Y_predictions and the y_test sample:

XAmount = X_test['Amount']

df = DataFrame(XAmount)
df.columns = ['Amount']

df["Y_predictions"] = pd.Series(rfc_pred)

df["Y_original"] = pd.Series(y_test)

# Show
df
# Out:
#             Amount  Y_predictions  Y_original
# 10550         0.00            NaN           2
# 4170      59706.26            0.0           1
# 10622         0.00            NaN           2
# 7453     299409.68            NaN           0
# 12106    537000.00            NaN           2
# 7159          0.00            NaN           0
# 12798  39000000.00            NaN           2
# 14515  20000000.00            NaN           2
# 183      499949.00            0.0           0
# 10492         0.00            NaN           2
# 14037   8000000.00            NaN           2
# 7499          0.00            NaN           0
# 7182      77195.00            NaN           0
# 6435      59845.00            NaN           1
# 7672      50000.00            NaN           2
# 5991      48373.00            NaN           0
# 13512    500000.00            NaN           2
# 14190  37500000.00            NaN           2
# 11488         0.00            NaN           2
# ...

# %% [markdown]
# # Logistic Regression:

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
predictions = logmodel.predict(X_test)

# %%
print(confusion_matrix(y_test,predictions))
print('\n')
print(classification_report(y_test,predictions))
# Out:
# [[ 142   26  796]
#  [  83   31 1469]
#  [  53   37 2201]]
#
#
#              precision    recall  f1-score   support
#
#           0       0.51      0.15      0.23       964
#           1       0.33      0.02      0.04      1583
#           2       0.49      0.96      0.65      2291
#
# avg / total       0.44      0.49      0.37      4838

# %%
print(predictions[0:1000])
# Out:
# [2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 0 2 2 2 0 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 0 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2 0 2 2 2 2 2 2 2 2 0 2 2 2 2 2
#  0 2 2 2 2 2 0 2 2 2 2 1 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 0 0 2 2 2 2 2 2 2 0 2 2 2 2 0 2 0 2 0 2 2
#  2 2 2 2 2 2 2 2 2 1 2 2 2 0 2 2 2 2 2 2 2 1 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 0 2 2 2 2 2 2 2 2 0 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 0 2
#  2 2 2 2 2 2 2 2 1 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 0 2 2 2 2 2 2 2
#  2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 0 2 2 2 2 2 2 0 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 1 2 2 2 2 2
# ...
